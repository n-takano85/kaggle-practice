# %%
import pandas as pd
# 最新版は名前が変わっているのでこれをインストール
# !pip install ydata-profiling
import pandas_profiling


train = pd.read_csv('./input/titanic/train.csv')
train =train.profile_report()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 7.4 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 7.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.5 MB/s  0:00:15m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.6/677.6 kB 6.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 4.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 6.6 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 7.3 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: matplotlib╸━━━━━━━━━━━━━ 14/21 [numba]ic]od]
#     Found existing installation: matplotlib 3.10.8━━━━━━━━━━━━ 14/21 [numba]
#     Uninstalling matplotlib-3.10.8:╸━━━━━━━━━━━━━ 14/21 [numba]
#       Successfully uninstalled matplotlib-3.10.80m━━━━━━━━━━━ 15/21 [matplotlib]
# ...

# %%
print(111)
# Out:
# 111
