# %%
for epoch in range(1, 11):
    loss = 0.5 / epoch 
    print(f"Epoch {epoch:02}: Loss = {loss:.4f}")
    #f文字列フォーマット f""とすると中の｛｝は変数扱いされる。
    # :02は０埋めで二桁表示、:.4fは小数点以下4桁までfloat（浮動小数点）表示
# Out:
# Epoch 01: Loss = 0.5000
# Epoch 02: Loss = 0.2500
# Epoch 03: Loss = 0.1667
# Epoch 04: Loss = 0.1250
# Epoch 05: Loss = 0.1000
# Epoch 06: Loss = 0.0833
# Epoch 07: Loss = 0.0714
# Epoch 08: Loss = 0.0625
# Epoch 09: Loss = 0.0556
# Epoch 10: Loss = 0.0500
